# %% [markdown]
# <h1>Mineração de Emoção em Textos com Python e NLTK<h1>

# %%
import nltk

# %% [markdown]
# Será utilizada uma base de treinamento com 538 frases
# 342 Negativos
# 196 Positivos

# %%
basetreinamento = [
('este trabalho e agradável','positivo'),
('gosto de ficar no seu aconchego','positivo'),
('fiz a adesão ao curso hoje','positivo'),
('eu sou admirada por muitos','positivo'),
('adoro como você e','positivo'),
('adoro seu cabelo macio','positivo'),
('adoro a cor dos seus olhos','positivo'),
('somo tão amáveis um com o outro','positivo'),
('sinto uma grande afeição por ele','positivo'),
('quero agradar meus filhos','positivo'),
('me sinto completamente amado','positivo'),
('eu amo você','positivo'),
('que grande alivio','positivo'),
('a dor esta amenizando finalmente','positivo'),
('acho que me apaixonei','positivo'),
('amar e maravilhoso','positivo'),
('estou me sentindo muito animada','positivo'),
('me sinto muito bem hoje','positivo'),
('como o luar e belo','positivo'),
('o dia esta muito bonito','positivo'),
('nossa como sou afortunado','positivo'),
('as maravilhas do mundo','positivo'),
('recebi muito carinho hoje do meus colegas','positivo'),
('estou me sentindo reconfortada hoje','positivo'),
('e muito bom estar com os amigos','positivo'),
('estou muito contente com o resultado dos testes','positivo'),
('essa pintura esta bem brilhante','positivo'),
('temos água em abundancia','positivo'),
('que roupa delicada','positivo'),
('você e um grande comediante','positivo'),
('que bondade a sua em vir aqui','positivo'),
('o amor e lindo','positivo'),
('nossa amizade vai durar para sempre','positivo'),
('estou eufórica com a noticia','positivo'),
('ele e realmente fiel a mim','positivo'),
('vou dar uma grande festa para comemorar meu aniversário','positivo'),
('graças a deus que eu enxerguei o certo','positivo'),
('essa e a melhor escolhas de todas','positivo'),
('o mais incrível e você minha bela','positivo'),
('e tão engraçado tentar explicar','positivo'),
('e emocionante estar neste lugar','positivo'),
('estou cativada pelo seu olhar','positivo'),
('estou loucamente apaixonada','positivo'),
('eu nunca tive duvidas','positivo'),
('estou rodeada pelo seu abraço','positivo'),
('eu vejo estrelas pelo caminho','positivo'),
('eu sinto o sol sempre que você esta por perto','positivo'),
('eu estou sorrindo de orelha a orelha','positivo'),
('isso vale a pena','positivo'),
('finalmente você colocou meu amor em primeiro lugar','positivo'),
('nós dançamos noite adentro','positivo'),
('seu amor e brilhante','positivo'),
('toquei muitos corações durante o meu caminho','positivo'),
('eu serei sua amiga e companheira','positivo'),
('você me traz de volta a vida','positivo'),
('você e como um sonho doce','positivo'),
('adoro este doce de frutas','positivo'),
('meu suco favorito','positivo'),
('estou agradecida pela ajuda','positivo'),
('e um enorme prazer ter você em nossa equipe','positivo'),
('trabalhar em equipe e o melhor','positivo'),
('me sinto flutuando no ar','positivo'),
('a brisa esta agradável hoje','positivo'),
('ótimo e compatível','positivo'),
('somos compatíveis um com o outro','positivo'),
('o órgão e compatível com o paciente','positivo'),
('estou contente fui aceita na faculdade','positivo'),
('fui aprovada no meu exame','positivo'),
('fui beneficiada pela minha empresa','positivo'),
('eu sou muito cativante','positivo'),
('estou contente com o apoio','positivo'),
('como este lugar e confortável','positivo'),
('e bom estar quente neste frio','positivo'),
('um elogio nunca e demais','positivo'),
('vou te chamar para comemorar','positivo'),
('e desejável a sua presença em nossa apresentação','positivo'),
('sou muito grata a você','positivo'),
('me dedico muito naquilo que faço','positivo'),
('estou completamente apaixonada ','positivo'),
('vamos agitar essa noite ','positivo'),
('você significa muito para mim','positivo'),
('vamos agir sem preconceitos e julgamentos','positivo'),
('finalmente completei a minha coleção, maravilhoso','positivo'),
('eu sou sua rainha ','positivo'),
('satisfatoriamente eu anuncio o vencedor dos jogos','positivo'),
('você me atrai facilmente ','positivo'),
('aquele rapaz e extremamente atraente','positivo'),
('sinto-me viva ','positivo'),
('sinto-me em paz ','positivo'),
('estamos tendo muito lucro','positivo'),
('muito bem esta tudo em ordem agora ','positivo'),
('podemos arrumar um emprego juntos ','positivo'),
('a arrumação esta terminada, que alívio','positivo'),
('o câncer e benigno ','positivo'),
('o amor e abundante','positivo'),
('vamos ser caridosos este natal','positivo'),
('com todo esse charme você irá atrair a todos','positivo'),
('nossa como você e charmoso querido ','positivo'),
('sou querida pelos meu amigos','positivo'),
('seja cuidadoso com os meus sentimentos','positivo'),
('estou comovido com tamanha caridade','positivo'),
('um chá quente e reconfortante','positivo'),
('que alegria ter vocês aqui ','positivo'),
('vamos aplaudir o vencedor ','positivo'),
('palmas para a aniversariante','positivo'),
('desejo a você tudo de bom','positivo'),
('hora de apreciar um bom vinho','positivo'),
('aprecio sua presença em minha escola','positivo'),
('anseio por seus próximos trabalhos','positivo'),
('maravilhoso jogo amistoso','positivo'),
('e ótimo que os ânimos tenham se apaziguado','positivo'),
('concretizei finalmente meu sonho','positivo'),
('você e abominável','negativo'),
('abomino a maneira como você age','negativo'),
('estou adoentado','negativo'),
('meu pai esta adoentado','negativo'),
('estamos todos doentes','negativo'),
('essa situação e muito amarga','negativo'),
('disse adeus amargamente','negativo'),
('tenho antipatia por aquela pessoa','negativo'),
('como pode ser tão antipática!','negativo'),
('que horrível seu asqueroso','negativo'),
('tenho aversão agente como você','negativo'),
('isso tudo e só chateação','negativo'),
('estou muito chateada com suas mentiras','negativo'),
('tão desagradável','negativo'),
('isso me desagrada completamente','negativo'),
('te desagrada isso','negativo'),
('estou com enjôos terríveis','negativo'),
('todos estão enfermos','negativo'),
('foi uma enfermidade terrível','negativo'),
('isso e muito grave','negativo'),
('não seja tão grosseiro','negativo'),
('você fez uma manobra ilegal','negativo'),
('sua indecente, não tem vergonha?','negativo'),
('você e malvado com as crianças','negativo'),
('que comentário maldoso','negativo'),
('sem escrúpulos você manipula a tudo','negativo'),
('sinto repulsa por você','negativo'),
('e repulsivo a maneira como olha para as pessoas','negativo'),
('estou indisposta','negativo'),
('a indisposição me atacou hoje','negativo'),
('acho que vou vomitar','negativo'),
('tem muito vomito lá','negativo'),
('que incomodo essa dor','negativo'),
('não me incomode nunca mais','negativo'),
('suas bobagens estão nos incomodando','negativo'),
('que nojo olha toda essa sujeira','negativo'),
('como isso está sujo','negativo'),
('tenho náuseas só de lembrar','negativo'),
('me sinto nauseada com o cheiro desta comida','negativo'),
('você esta obstruindo a passagem de ar','negativo'),
('você esta terrivelmente doente','negativo'),
('olhe que feia esta roupa','negativo'),
('que atitude deplorável','negativo'),
('nossa como você e feio','negativo'),
('muito mau tudo isso','negativo'),
('estou desgostoso com você','negativo'),
('você cortou o meu assunto','negativo'),
('para que tanta chateação?','negativo'),
('esse perfume e enjoativo','negativo'),
('ser perigoso não nada bom','negativo'),
('você e perigoso demais para minha filhas','negativo'),
('que fetido este esgoto','negativo'),
('que fedido você esta','negativo'),
('que cachorro malcheiroso','negativo'),
('hora que ultraje','negativo'),
('e ultrajante da sua parte','negativo'),
('situação desagradável essa','negativo'),
('você só me da desgosto','negativo'),
('tenho aversão a pessoas assim','negativo'),
('antipatia e um mal da sociedade','negativo'),
('que criatura abominável','negativo'),
('e depressiva a maneira como você vê o mundo','negativo'),
('me desagrada sua presença na festa','negativo'),
('sinto asco dessa coisa','negativo'),
('que hediondo!','negativo'),
('vou golfar o cafe fora','negativo'),
('hora que garota detestável!','negativo'),
('estou nauseada','negativo'),
('isso que você disse foi muito grave','negativo'),
('não seja obsceno na frente das crianças','negativo'),
('não seja rude com as visitas','negativo'),
('esse assunto me da repulsa','negativo'),
('que criança terrivelmente travessa','negativo'),
('que criança mal educada','negativo'),
('estou indisposta te dar o divorcio','negativo'),
('tão patetico, não tem nada mais rude para dizer?','negativo'),
('por motivo torpe, com emprego de meio cruel e com impossibilidade de defesa para a vítima','negativo'),
('a inveja e tão vil e vergonhosa que ninguem se atreve a confessá-la','negativo'),
('o miserável receio de ser sentimental e o mais vil de todos os receios modernos','negativo'),
('travesso gato quando fica com saudades do dono mija no sapato','negativo'),
('isso e um ato detestável e covarde','negativo'),
('revelam apenas o que e destrutivo e detestável para o povo','negativo'),
('não sei como e a vida de um patife, mais a de um homem honesto e abominável','negativo'),
('há coisas que temos que suportar para não acharmos a vida insuportável','negativo'),
('as injurias do tempo e as injustiças do homem','negativo'),
('odioso e desumano','negativo'),
('você não publicará conteúdo odiento, pornográfico ou ameaçador','negativo'),
('rancoroso e reprimido','negativo'),
('não há animal mais degradante, estúpido, covarde, lamentável, egoísta, rancoroso e invejoso do que o homem','negativo'),
('o virulento debate ente políticos','negativo'),
('eu imploro, não me matem!','negativo'),
('tem certeza que não e perigoso?','negativo'),
('não tenho certeza se e seguro','negativo'),
('tenho que correr pra não me pegarem','negativo'),
('socorro! ele queria roubar os meus doces!','negativo'),
('esse cara está me perseguindo','negativo'),
('não entro lá, e um lugar muito perigoso','negativo'),
('este lugar continua assustador','negativo'),
('na selva tem muitos animais perigosos','negativo'),
('avancem com cautela','negativo'),
('este lugar está silencioso de mais, cuidado!','negativo'),
('por favor, deixe-me viver!','negativo'),
('vou ficar sem mesada se tirar nota baixa','negativo'),
('parece que tem olhos nos vigiando','negativo'),
('eu temo que a sentença do juiz possa ser negativa','negativo'),
('mas essa missão e arriscada','negativo'),
('salvem-se quem puder!','negativo'),
('meu plano pode ser descoberto','negativo'),
('não tive culpa, juro não fui eu','negativo'),
('tenho que tomar cuidado com o lobisomem','negativo'),
('se eu não achar, ele vai descobrir a verdade','negativo'),
('meu deus, ele desapareceu!','negativo'),
('tomara que eles não me vejam daqui!','negativo'),
('mantenha isso em segredo, se descobrirem estaremos ferrados','negativo'),
('por favor, me soltem, eu sou inocente','negativo'),
('estou ouvindo passos atrás de mim','negativo'),
('eu vou pedir socorro!','negativo'),
('cuidado com as curvas na estrada','negativo'),
('não sei não, parece perigoso','negativo'),
('estou tremendo de medo!','negativo'),
('socorro, eu vou cair!','negativo'),
('eu não vou ate a floresta negra, e muito perigoso','negativo'),
('ouço passos na minha direção','negativo'),
('acho que está arriscado de mais','negativo'),
('vamos voltar, e muito perigoso','negativo'),
('fuja, se não acabaremos mortos','negativo'),
('receio por não me livrar desta situação','negativo'),
('socorro! ele está armado!','negativo'),
('ei cuidado, você vai bater no poste!','negativo'),
('socorro, nós estamos afundando','negativo'),
('e serio, cuidado com essa arma!','negativo'),
('os tubarões estão atacando!','negativo'),
('sinto arrepios quando fico sozinho no escuro','negativo'),
('calma, eu não estou com o dinheiro','negativo'),
('eu acho que estou sendo enganado','negativo'),
('ligeiro, temos que fugir depressa','negativo'),
('tem um crocodilo selvagem vindo para cá','negativo'),
('se ficarmos quietos eles não vão nos achar','negativo'),
('fuja! o tigre parece faminto','negativo'),
('estou sem saída, preciso de um milagre','negativo'),
('tire isso de mim! socorro!','negativo'),
('não sei nadar, vou me afogar!','negativo'),
('não tenho certeza se e seguro','negativo'),
('vou apanhar se meus pais verem meu boletim','negativo'),
('não consigo sair daqui!','negativo'),
('se sair tão tarde, poderei ser assaltada','negativo'),
('não me deixe por favor!','negativo'),
('espere, não pode me largar aqui sozinho','negativo'),
('temo pela sua segurança','negativo'),
('eu te entrego o dinheiro, por favor não me mate!','negativo'),
('ele vai levar todo o meu dinheiro','negativo'),
('não dirija tão rápido assim','negativo'),
('me descobriram, irão me prender!','negativo'),
('só espero que não me façam nenhum mal','negativo'),
('vou me afogar, me ajudem a sair da água','negativo'),
('não estaremos a salvo aqui','negativo'),
('não quero nem pensar no que pode acontecer','negativo'),
('nessa cidade e uma desgraça atrás da outra','negativo'),
('alguem esta me ligando, estou assustado','negativo'),
('isso não e remedio, não me matem','negativo'),
('eu não confio nele, tenho que ter cautela','negativo'),
('muita cautela','negativo'),
('vou ser descoberto, meu deus','negativo'),
('receio que terei de ir','negativo'),
('a noite e muito perigosa','negativo'),
('estou estremecendo com essa casa','negativo'),
('olha aquela criatura se movendo monstruosamente','negativo'),
('não agüento este suspense','negativo'),
('afugente os cães','negativo'),
('estou chocado e amedrontado com este assassinato brutal','negativo'),
('e preciso afugenta com ímpeto este medo do inferno','negativo'),
('seu políticos usam suas forças para afugentar e amedrontar o povo','negativo'),
('o objetivo disso e apenas me amedrontar mais','negativo'),
('isso me apavora','negativo'),
('ele a feriu profundamente','negativo'),
('vou despejar minha cólera em você','negativo'),
('me sinto atormentado','negativo'),
('não me contrarie','negativo'),
('vou destruir tudo  que foi construído','negativo'),
('não consigo terminar este trabalho, e muito frustrante','negativo'),
('me frustra a sua presença aqui','negativo'),
('esta comida me parece muito ruim','negativo'),
('você me destrói','negativo'),
('estamos separados','negativo'),
('estou odiando este vestido','negativo'),
('não pude comprar meu celular hoje','negativo'),
('ela e uma garota ruim','negativo'),
('estivemos em um show horroroso','negativo'),
('o ingresso estava muito caro','negativo'),
('se eu estragar tudo vai por água a baixo','negativo'),
('não possuo dinheiro algum','negativo'),
('sou muito pobre','negativo'),
('vai prejudicar a todos esta nova medida','negativo'),
('ficou ridículo','negativo'),
('este sapato esta muito apertado','negativo'),
('a musica e uma ofensa aos meus ouvidos','negativo'),
('não consigo terminar uma tarefa muito difícil','negativo'),
('reprovei em minha graduação','negativo'),
('estou muito chateado com tudo','negativo'),
('eu odeio em você','negativo'),
('e um desprazer conhecê-lo','negativo'),
('estou desperdiçando minhas ferias','negativo'),
('e muito ruim este jogo','negativo'),
('vamos ter muito rancor pela frente','negativo'),
('não achei que seria tão terrível','negativo'),
('vou vetar o orçamento ao cliente','negativo'),
('meus pais não consentiram nosso casamento','negativo'),
('eu odiei este perfume','negativo'),
('seu descaso e frustrante','negativo'),
('me sinto completamente amarga','negativo'),
('desprezo muito o seu trabalho','negativo'),
('estamos descontentes por nossa família','negativo'),
('vou infernizar a sua empresa','negativo'),
('estou furioso com estes valores','negativo'),
('obrigaram o rapaz a sair','negativo'),
('como ele pode deixar de lado?','negativo'),
('são apenas injurias sobre mim','negativo'),
('estou enfurecido com a situação dessa empresa','negativo'),
('estou com o diabo no corpo','negativo'),
('isso foi diabólico','negativo'),
('tenho aversão à gente chata','negativo'),
('não vou perdoar sua traição','negativo'),
('esse dinheiro sujo e corrupto','negativo'),
('eles me crucificam o tempo todo','negativo'),
('eu vou enlouquecer com todo este barulho','negativo'),
('não agüento todo esse assedio','negativo'),
('cólera do dragão','negativo'),
('isso e ridículo!','negativo'),
('da próxima vez, vou inventar tudo sozinho','negativo'),
('seus tolos! deixaram ele escapar!','negativo'),
('jamais te perdoarei','negativo'),
('o que e isso? outra multa','negativo'),
('você passou dos limites!','negativo'),
('sente-se e cale a boca','negativo'),
('ingratosvermesvocês me pagam!','negativo'),
('saiam da dai, se não arranco vocês dai!','negativo'),
('você já me causou problemas suficientes','negativo'),
('isso foi a gota d’agua','negativo'),
('o que você tem com isso?','negativo'),
('não vejo a hora de me livrar de você','negativo'),
('já entendi a jogada seus safados!','negativo'),
('você não merece piedade','negativo'),
('saia de perto de mim','negativo'),
('suma daqui, ou arranco seu couro!','negativo'),
('estou revoltado com essa situação','negativo'),
('seu idiota!','negativo'),
('não, eu não vou te emprestar dinheiro!','negativo'),
('você não passa de um cafajeste! vai embora','negativo'),
('pare de frescura e vá trabalhar','negativo'),
('eles merecem uma lição','negativo'),
('ainda estou muito bravo com você','negativo'),
('eu preciso surrar aquela chantagista','negativo'),
('olha o que você fez! derramou!','negativo'),
('você está pedindo pra apanhar!','negativo'),
('me deixa em paz!','negativo'),
('morra maldito, morra!','negativo'),
('você e mais irritante de perto','negativo'),
('e bom fechar o bico','negativo'),
('magicamente você me surpreendeu','positivo'),
('e imenso esse globo','positivo'),
('isso e tremendamente interessante','positivo'),
('meu bilhete for sorteado, inacreditável!','positivo'),
('um assalto a mão armada!','positivo'),
('incrível, cabe em qualquer lugar!','positivo'),
('você por aqui?','positivo'),
('não dá pra acreditar no que ela me contou','positivo'),
('os convidados já estão chegando!','positivo'),
('puxa vida! nunca nos livramos de alguem tão depressa','positivo'),
('micha carteira sumiu, eu estava com ela na mão','positivo'),
('oh! um disco voador','positivo'),
('amigos, que bela surpresa!','positivo'),
('nunca pensei que veria isso e perto','positivo'),
('nem acredito que comi tanto','positivo'),
('não acredito que veio me ver','positivo'),
('não acredito que e  tão descarado','positivo'),
('me surpreende sua falta de tato','positivo'),
('o predio onde eles moravam desabou!','positivo'),
('inacreditável um bolo tão grande','positivo'),
('e serio mesmo? não dá pra acreditar','positivo'),
('como assim não vai ao nosso encontro?','positivo'),
('como assim não tem ninguem em casa?','positivo'),
('ue, mas para onde ele foi?!','positivo'),
('por essa eu não esperava','positivo'),
('nossa, olha só que mergulho','positivo'),
('minha esposa está grávida!','positivo'),
('meu dinheiro sumiu!','positivo'),
('e verdade que os dois terminaram?!?','positivo'),
('caramba, nem vi você chegar','positivo'),
('nossa, como pode alguem cozinhar tão mal?','positivo'),
('nossa que incrível','positivo'),
('a fórmula sumiu!','positivo'),
('eu nem acredito que já estou terminando o curso','positivo'),
('não acredito que esta aqui comigo novamente','positivo'),
('está escondendo algo de nós!','positivo'),
('como assim, ainda não terminou a tarefa','positivo'),
('pensei que já estivesse pronta!','positivo'),
('opa! quem apagou a luz?','positivo'),
('caramba! aonde vai tão rápido?','positivo'),
('estamos seguindo o caminho errado!','positivo'),
('quatro reais o litro da gasolina!','positivo'),
('me assustei ao vê-lo desse jeito!','positivo'),
('minha mãe está grávida, acredita nisso?','positivo'),
('parece mentira você ter crescido tanto','positivo'),
('me surpreende sua imaginação','positivo'),
('suas roupas são realmente lindas','positivo'),
('com consegue ser tão bela?','positivo'),
('essa e realmente uma casa deslumbrante','positivo'),
('superou minhas expectativas','positivo'),
('e admirável a maneira como se comporta','positivo'),
('isso e realmente chocante','positivo'),
('algumas noticias me surpreenderam no noticiário','positivo'),
('surpreendente sua festa','positivo'),
('estou tremendo de alegria','positivo'),
('chocou grande parte do mundo','positivo'),
('eu ficaria muito espantado com a sua vinda','positivo'),
('ele e admirável','positivo'),
('sua beleza me surpreendeu','positivo'),
('seus olhos são surpreendentemente verdes','positivo'),
('os políticos se surpreendem quando alguem acredita neles','positivo'),
('estou perplexa com essas denuncias','positivo'),
('fiquei perplexo com suas palavras','positivo'),
('estou abismado com sua prosa','positivo'),
('eu ficaria realmente abismado se me dissessem isso','positivo'),
('o grupo foi surpreendido enquanto lavava o carro','positivo'),
('estou boquiaberto com as imagens','positivo'),
('estou boquiaberto com essas suas palavras','positivo'),
('esse quadro e maravilhoso','positivo'),
('este carro me deixou maravilhado','positivo'),
('estou maravilhada','positivo'),
('essa expectativa esta me matando','positivo'),
('vou caminhar sempre na expectativa de encontrá-lo','positivo'),
('você emudece minhas palavras','positivo'),
('minhas palavras vão emudecer se não parar de me surpreender','positivo'),
('a mulher e um efeito deslumbrante da natureza','positivo'),
('estou deslumbrada com essas jóias','positivo'),
('isso e romântico e deslumbrante','positivo'),
('isso pode ser surpreendentemente deslumbrante','positivo'),
('trabalho deslumbrante','positivo'),
('essas pessoas são esplêndida','positivo'),
('e esplendido como o ceu se encontra no momento','positivo'),
('e um carro fantástico','positivo'),
('um edifício realmente fantástico','positivo'),
('por favor não me abandone','negativo'),
('não quero ficar sozinha','negativo'),
('não me deixe sozinha','negativo'),
('estou abatida','negativo'),
('ele esta todo abatido','negativo'),
('tão triste suas palavras','negativo'),
('seu amor não e mais meu','negativo'),
('estou aborrecida','negativo'),
('isso vai me aborrecer','negativo'),
('estou com muita aflição','negativo'),
('me aflige o modo como fala','negativo'),
('estou em agonia com meu intimo','negativo'),
('não quero fazer nada','negativo'),
('me sinto ansiosa e tensa','negativo'),
('não consigo parar de chorar','negativo'),
('não consigo segurar as lagrimas','negativo'),
('e muita dor perder um ente querido','negativo'),
('estou realmente arrependida','negativo'),
('acho que o carma volta, pois agora sou eu quem sofro','negativo'),
('você não cumpriu suas promessas','negativo'),
('me sinto amargurada','negativo'),
('coitado esta tão triste','negativo'),
('já e tarde de mais','negativo'),
('nosso amor acabou','negativo'),
('essa noite machuca só para mim','negativo'),
('eu não estou mais no seu coração','negativo'),
('você mudou comigo','negativo'),
('quando eu penso em você realmente dói','negativo'),
('como se fosse nada você vê minhas lagrimas','negativo'),
('você disse cruelmente que não se arrependeu','negativo'),
('eu nunca mais vou te ver','negativo'),
('ela esta com depressão','negativo'),
('a depressão aflige as pessoas','negativo'),
('estar depressivo e muito ruim','negativo'),
('estou derrotada e deprimida depois deste dia','negativo'),
('e comovente te ver dessa maneira','negativo'),
('e comovente ver o que os filhos do brasil passam','negativo'),
('como me sinto culpada','negativo'),
('estou abatida','negativo'),
('a ansiedade tomou conta de mim','negativo'),
('as pessoas não gostam do meu jeito','negativo'),
('adeus passamos bons momentos juntos','negativo'),
('sinto sua falta','negativo'),
('ele não gostou da minha comida','negativo'),
('estou sem dinheiro para a comida','negativo'),
('queria que fosse o ultimo dia da minha vida','negativo'),
('você está com vergonha de mim','negativo'),
('ela não aceitou a minha proposta','negativo'),
('era o meu ultimo centavo','negativo'),
('reprovei de ano na faculdade','negativo'),
('afinal você só sabe me desfazer','negativo'),
('eu falhei em tudo nessa vida','negativo'),
('eu fui muito humilhado','negativo'),
('e uma história muito triste','negativo'),
('ninguem acredita em mim','negativo'),
('eu não sirvo para nada mesmo','negativo'),
('droga, não faço nada direito','negativo'),
('sofrimento em dobro na minha vida','negativo'),
('fui demitida essa semana','negativo'),
('as crianças sofrem ainda mais que os adultos','negativo'),
('pra mim um dia e ruim, o outro e pior','negativo'),
('de repente perdi o apetite','negativo'),
('oh que dia infeliz','negativo'),
('estamos afundados em contas','negativo'),
('nem um milagre pode nos salvar','negativo'),
('só me resta a esperança','negativo'),
('pior que isso não pode ficar','negativo'),
('meu salário e baixo','negativo'),
('não passei no vestibular','negativo'),
('ninguem se importa comigo','negativo'),
('ninguem lembrou do meu aniversário','negativo'),
('tenho tanto azar','negativo'),
('o gosto da vingança e amargo','negativo'),
('sou uma mulher amargurada depois de que você me deixou','negativo'),
('estou desanimada com a vida','negativo'),
('e um desanimo só coitadinha','negativo'),
('a derrota e depressiva','negativo'),
('discriminar e desumano','negativo'),
('que desanimo','negativo'),
('e uma desonra para o pais','negativo'),
('a preocupação deveria nos levar a ação não a depressão','negativo'),
('passamos ao desalento e a loucura','negativo'),
('aquele que nunca viu a tristeza nunca reconhecerá a alegria','negativo'),
('cuidado com a tristeza ela e um vicio','negativo')]

# %% [markdown]
# E uma base de testes com 228 frases
# 84 positivas
# 144 negativas

# %%
baseteste =[('não precisei pagar o ingresso','positivo'),
('se eu ajeitar tudo fica bem','positivo'),
('minha fortuna ultrapassa a sua','positivo'),
('sou muito afortunado','positivo'),
('e benefico para todos esta nova medida','positivo'),
('ficou lindo','positivo'),
('achei esse sapato muito simpático','positivo'),
('estou ansiosa pela sua chegada','positivo'),
('congratulações pelo seu aniversário','positivo'),
('delicadamente ele a colocou para dormir','positivo'),
('a musica e linda','positivo'),
('sem musica eu não vivo','positivo'),
('conclui uma tarefa muito difícil','positivo'),
('conclui minha graduação','positivo'),
('estou muito contente com tudo','positivo'),
('eu confio em você','positivo'),
('e um prazer conhecê-lo','positivo'),
('o coleguismo de vocês e animador','positivo'),
('estou aproveitando as ferias','positivo'),
('vamos aproveitar as ferias','positivo'),
('e muito divertido este jogo','positivo'),
('vamos ter muita diversão','positivo'),
('não achei que me divertiria tanto assim','positivo'),
('vou consentir o orçamento ao cliente','positivo'),
('com o consentimento dos meus pais podemos nos casar','positivo'),
('eu adorei este perfume','positivo'),
('sua bondade e cativante','positivo'),
('estou despreocupada','positivo'),
('não me preocupo com o que aconteceu','positivo'),
('me sinto completamente segura','positivo'),
('estimo muito o seu trabalho','positivo'),
('somos estimados por nossa família','positivo'),
('concretizamos nossa ideia','positivo'),
('nosso ideal foi alcançado','positivo'),
('estamos muito felizes juntos','positivo'),
('estou tão animada com os preparativos para o casamento','positivo'),
('você será muito amado meu filho','positivo'),
('os apaixonados são maravilhosos','positivo'),
('agradeço imensamente o seu apoio nestes dias','positivo'),
('esta comida me parece muito atraente','positivo'),
('você me completa','positivo'),
('poderemos completar o projeto hoje!','positivo'),
('estamos namorando','positivo'),
('estou namorando este vestido a um tempo','positivo'),
('pude comprar meu celular hoje','positivo'),
('e um deleite poder compartilhar minhas vitórias','positivo'),
('ela e um boa garota','positivo'),
('estivemos em um ótimo show','positivo'),
('o mundo e feio como o pecado','negativo'),
('a coisa mais difícil de esconder e aquilo que não existe','negativo'),
('você errou feio aquele gol','negativo'),
('nunca vou me casar sou muito feia','negativo'),
('os golpes da adversidade são terrivelmente amargos','negativo'),
('os homem ficam terrivelmente chatos','negativo'),
('abominavelmente convencido','negativo'),
('terrivelmente irritado','negativo'),
('as instituições publicas estão terrivelmente decadentes','negativo'),
('a população viveu em isolamento por muito tempo','negativo'),
('estou terrivelmente preocupada','negativo'),
('o nacionalismo e uma doença infantil','negativo'),
('se me es antipático a minha negação esta pronta','negativo'),
('muitos documentários sobre esse casal antipático','negativo'),
('sua beleza não desfaça sua antipatia','negativo'),
('esta e uma experiência desagradável','negativo'),
('desagradável estrago nos banheiros','negativo'),
('o mais irritante no amor e que se trata de um crime que precisa de um cúmplice','negativo'),
('a situação nos causa grande incomodo','negativo'),
('estou preocupado com o incomodo na garganta','negativo'),
('simplesmente não quero amolação da policia','negativo'),
('você e uma criaturinha muito impertinente','negativo'),
('o peso e a dor da vida','negativo'),
('me arrependo amargamente de minhas ações','negativo'),
('o destino e cruel e os homens não são dignos de compaixão','negativo'),
('o ódio conduz ao isolamento cruel e ao desespero','negativo'),
('encerrou com o massacre mais repudiável e asqueroso que se conhece','negativo'),
('de mal gosto e asqueroso','negativo'),
('tudo e inserto neste mundo hediondo','negativo'),
('o crime de corrupção e um crime hediondo','negativo'),
('o rio esta fetido e de cor escura','negativo'),
('muito lixo no rio o deixa malcheiroso','negativo'),
('existe uma laranja podre no grupo e já desconfiamos quem e','negativo'),
('foi de repente estou machucado e me sentindo enjoado','negativo'),
('eu fiquei enojado','negativo'),
('daqui alguns meses vou embora deste pais que já estou nauseado','negativo'),
('que abominável esse montro!','negativo'),
('vamos alarmar a todos sobre a situação','negativo'),
('estou amedrontada','negativo'),
('estou com muito medo da noite','negativo'),
('ele esta me ameaçando a dias','negativo'),
('quanta angustia','negativo'),
('estou angustiada','negativo'),
('angustiadamente vou sair e casa','negativo'),
('isso me deixa apavorada','negativo'),
('você esta me apavorando','negativo'),
('estou desconfiada de você','negativo'),
('não confio em você','negativo'),
('ate o cachorro está apavorado','negativo'),
('estou assustado com as ações do meu colega','negativo'),
('agora se sente humilhado, apavorado','negativo'),
('assustou a população e provocou mortes','negativo'),
('estou com dificuldades para respirar e muito assustado','negativo'),
('os policiais se assustaram quando o carro capotou','negativo'),
('o trabalhador e assombrado pelo temor do desemprego','negativo'),
('este lugar e mal assombrado','negativo'),
('estou assombrado pela crise financeira','negativo'),
('mesmo aterrorizado lembro de você','negativo'),
('aterrorizado e suando frio','negativo'),
('um grupo de elefantes selvagens tem aterrorizado vilas','negativo'),
('me sinto intimidada pela sua presença','negativo'),
('tenho medo de ser advertida novamente','negativo'),
('estou correndo o risco de ser advertido','negativo'),
('estou correndo riscos de saúde','negativo'),
('os riscos são reais','negativo'),
('podemos perder muito dinheiro com essa investida','negativo'),
('socorro, fui intimado a depor','negativo'),
('fui notificado e estou com medo de perde a guarda da minha filha','negativo'),
('estou angustiada com meus filhos na rua','negativo'),
('e abominável o que fazem com os animais','negativo'),
('foi terrível o tigre quase o matou','negativo'),
('me advertiram sobre isso','negativo'),
('ate que enfim, não agüentava mais te esperar','negativo'),
('eu quero meu dinheiro de volta agora!','negativo'),
('eu odeio a escola!','negativo'),
('vou fazer picadinho de você','negativo'),
('detesto trabalhar no verão','negativo'),
('quero minha comida, e quero agora!','negativo'),
('melhor você recolher minhas compras agora!','negativo'),
('quero descer agora sua maluca','negativo'),
('vou reclamar com o gerente!','negativo'),
('vai engolir o que disse!','negativo'),
('ele me ridiculariza diante de todos','negativo'),
('não quero mais saber de você','negativo'),
('vejo você na cadeia safado!','negativo'),
('agora vou ter que pagar mais isso ainda!','negativo'),
('saia logo do banheiro!','negativo'),
('suba já para o seu quarto!','negativo'),
('eu falei para calar a boca seu idiota!','negativo'),
('eu disse para você cair fora!','negativo'),
('não agüento mais que fiquem me culpando sem motivo!','negativo'),
('não suporto olhar na sua cara!','negativo'),
('eu não sou um elefante','negativo'),
('juro que se olhar pra mim eu o mato!','negativo'),
('chega, não quero saber mais deste assunto','negativo'),
('como pode ser tão burro?','negativo'),
('não me aborreça seu moleque','negativo'),
('não quero me aborrecer com estas bobagens','negativo'),
('ele me agrediu!','negativo'),
('eu amaldiçôo você e a sua família','negativo'),
('não me amole','negativo'),
('não venha me amolar','negativo'),
('isso tudo e uma tormenta','negativo'),
('eu vou matar você','negativo'),
('para que simplificar se você pode sempre complicar','negativo'),
('isso esta me enlouquecendo','negativo'),
('estou furiosa com você','negativo'),
('isso mesmo fique furioso','negativo'),
('esses livros são magníficos','positivo'),
('esse vinho e magnífico','positivo'),
('seria magnífico ver o esperaculo','positivo'),
('o casamento foi estupendo','positivo'),
('e um jogador bárbaro estupendo','positivo'),
('esse dia esta excelente','positivo'),
('o cantor estava excelente','positivo'),
('o universo e assombroso','positivo'),
('o amor e sublime','positivo'),
('sua sublime atuação','positivo'),
('e formidável meu caro walter','positivo'),
('como e formidável a presença de todos','positivo'),
('e formidável ter a quem dizer adeus','positivo'),
('e um conselheiro formidável o seu','positivo'),
('o artigo foi formidável','positivo'),
('pica pau e um destaque no imaginário brasileiro','positivo'),
('ah! o absoluto do imaginário','positivo'),
('isso foi surreal','positivo'),
('uma historia completamente surreal','positivo'),
('essas pinturas beiram o surreal','positivo'),
('você nem acreditam de tão surreal','positivo'),
('incrível!','positivo'),
('fiquei pasma com tudo isso','positivo'),
('você me deixa pasmo','positivo'),
('estou admirado com a sua astucia','positivo'),
('que bela surpresa você me fez','positivo'),
('não acredito que fez isso!','positivo'),
('isso foi apavorante','positivo'),
('isso tão de repente','positivo'),
('estou chocada com isso','positivo'),
('estou surpresa e desconsertada','positivo'),
('esta realmente deslumbrante querida','positivo'),
('fiquei completamente sem plavras','positivo'),
('e espantoso o modo como ele nos olha','positivo'),
('incrivel você estar aqui','positivo'),
('que fantástica festa minha querida','positivo'),
('isso tudo e um erro','negativo'),
('eu sou errada eu sou errante','negativo'),
('tenho muito dó do cachorro','negativo'),
('e dolorida a perda de um filho','negativo'),
('essa tragedia vai nos abalar para sempre','negativo'),
('perdi meus filhos','negativo'),
('perdi meu curso','negativo'),
('sou só uma chorona','negativo'),
('você e um chorão','negativo'),
('se arrependimento matasse','negativo'),
('me sinto deslocado em sala de aula','negativo'),
('foi uma passagem fúnebre','negativo'),
('nossa condolências e tristeza a sua perda','negativo'),
('desanimo, raiva, solidão ou vazies, depressão','negativo'),
('vivo te desanimando','negativo'),
('estou desanimado','negativo'),
('imperador sanguinário, depravado e temeroso','negativo'),
('meu ser esta em agonia','negativo'),
('este atrito entre nos tem que acabar','negativo'),
('a escuridão desola meu ser','negativo'),
('sua falsa preocupação','negativo'),
('sua falsidade me entristece','negativo'),
('quem esta descontente com os outros esta descontente consigo próprio','negativo'),
('a torcida esta descontente com a demissão do tecnico','negativo'),
('estou bastante aborrecido com o jornal','negativo'),
('me sinto solitário e entediado','negativo'),
('a vida e solitária para aqueles que não são falsos','negativo'),
('como com compulsão depois da depressão','negativo'),
('estou me desencorajando a viver','negativo'),
('ele desencoraja minhas vontades','negativo'),
('isso vai deprimindo por dentro','negativo'),
('acho que isso e defeituoso','negativo'),
('os remedios me derrubam na cama','negativo'),
('a depressão vai me derrubar','negativo'),
('suas desculpas são falsas','negativo'),
('não magoe as pessoas','negativo')]

# %% [markdown]
# A base de stopwords utilizada será a existente do NLTK. Stopwords são palavras que não são relevantes para a análise

# %%
stopwordsnltk = nltk.corpus.stopwords.words('portuguese')

# %% [markdown]
# A próxima função remove as stopwords das frases da base

# %%
def removestopwords(texto):
    frases=[]
    for (palavras, emocao) in texto:
        semstop = [p for p in palavras.split() if p not in stopwordsnltk]
        frases.append((semstop, emocao))
    return frases

# %% [markdown]
# Em seguida, é removido o radical das palavras, processo chamado de stemming, e armazenado na variável frasescomstemming. Esse processo tem a finalidade de reduzir o tamanho das palavras para armazenamento.
# O processo é feito tanto para a base treinamento, quanto para a base de teste.

# %%
def aplicastemmer(texto):
    stemmer = nltk.stem.RSLPStemmer()
    frasesstemming = []
    for [palavras, emocao] in texto:
        comstemming = [str(stemmer.stem(p)) for p in palavras.split() if p not in stopwordsnltk]
        frasesstemming.append((comstemming, emocao))
    return frasesstemming

frasescomstemmingtreinamento = aplicastemmer(basetreinamento)
frasescomstemmingtreinamento = aplicastemmer(baseteste)

# %% [markdown]
# Para listar todas as palavras da base, usamos essa função, sem as stopwords e com stemming

# %%
def buscapalavras(frases):
	todaspalavras = []
	for (palavras, emocao) in frases:
		todaspalavras.extend(palavras)
	return todaspalavras

palavras = buscapalavras(frasescomstemmingtreinamento)
#print(palavras)

# %% [markdown]
# Extração das palavras unicas existentes na base de dados

# %%
def buscafrequencia(palavras):
	palavras = nltk.FreqDist(palavras)
	return palavras

frequencia = buscafrequencia(palavras)
#print(frequencia.most_common(50))

def buscapalavrasunicas(frequencia):
	freq = frequencia.keys()
	return freq
	
palavrasunicas = buscapalavrasunicas(frequencia)
#print(palavrasunicas)

# %% [markdown]
# Extração das palavras de cada frase

# %%
def extratorpalavras(documento):
    doc = set(documento)
    caracteristicas = {}
    for palavras in palavrasunicas:
        caracteristicas['%s' % palavras] = (palavras in doc)
    return caracteristicas

caracteristicasfrase = extratorpalavras(['am', 'nov', 'dia'])
#print(caracteristicasfrase)

# %% [markdown]
# Extração das palavras de todas as frases (Usada na tabela de probabilidade)

# %%
basecompleta = nltk.classify.apply_features(extratorpalavras, frasescomstemmingtreinamento)
#print(basecompleta)

# %% [markdown]
# Construção da tabela de probabilidade

# %%
classificador = nltk.NaiveBayesClassifier.train(basecompleta)
print("Exibe os resultados possíveis: ")
print(classificador.labels())
print("Exibe as estatísticas sobre os dados da base. Ex: Quando dia = true, as chances de a frase ser categorizada como alegria é maior que medo.")
print(classificador.show_most_informative_features(5))
# Out:
# Exibe os resultados possíveis:
# ['positivo', 'negativo']
# Exibe as estatísticas sobre os dados da base. Ex: Quando dia = true, as chances de a frase ser categorizada como alegria é maior que medo.
# Most Informative Features
#                  acredit = True           positi : negati =     11.0 : 1.0
#                     real = True           positi : negati =      5.2 : 1.0
#                       am = True           positi : negati =      5.2 : 1.0
#                   palavr = True           positi : negati =      5.2 : 1.0
#                     algu = True           positi : negati =      4.1 : 1.0
# None

# %% [markdown]
# Classificando uma frase teste. Ao aplicar no classificador, já realiza a remoção das stopwords.

# %%
teste = 'Eu sinto amor por você'
print("Frase teste: %s" % teste)
testestemming = []
stemmer = nltk.stem.RSLPStemmer()
for (palavras) in teste.split():
	comstem = [p for p in palavras.split()]
	testestemming.append(str(stemmer.stem(comstem[0])))
print("Stemming: %s" %testestemming)

novo = extratorpalavras(testestemming)
#print(novo)

print("Sentimento: %s" % classificador.classify(novo))
distribuicao = classificador.prob_classify(novo)
for classe in distribuicao.samples():
    print("%s: %f%%" % (classe, distribuicao.prob(classe)*100))
# Out:
# Frase teste: Eu sinto amor por você
# Stemming: ['eu', 'sint', 'am', 'por', 'voc']
# Sentimento: positivo
# positivo: 52.635071%
# negativo: 47.364929%
